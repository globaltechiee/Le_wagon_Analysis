# %% [markdown]
# ### Crude oil Production excersice

# %% [markdown]
# ## Comparing with Crude Oil Production

# %%
#IPython
# %matplotlib inline
import matplotlib
import pandas as pd
import numpy as np

# %%
file = "U.S._natural_gas_production.csv"
gas_df = pd.read_csv(file)
gas_df.head()
# Out:
#         Month   U.S.  Alaska  Arkansas  Kansas  Other States  \
# 0  2008-06-01  70626    8875      1196    1024          2995
# 1  2008-07-01  71137    8375      1256    1034          3150
# 2  2008-08-01  70760    8739      1313    1033          3092
# 3  2008-09-01  63984    9221      1316    1032          2953
# 4  2008-10-01  69464    9674      1375    1026          3113
#
#    Federal Offshore--Gulf of Mexico  Wyoming  West Virginia  Utah  \
# 0                              7339     6839            670  1198
# 1                              7468     6940            674  1200
# 2                              6868     6835            678  1277
# 3                              2100     6447            657  1276
# 4                              4368     6909            692  1241
#
#    Pennsylvania  Texas  Oklahoma  Ohio  North Dakota  New Mexico  Montana  \
# 0           540  21446      5241   224           243        3975      323
# ...

# %% [markdown]
# Create a new dataframe for the oil using the pd.read_csv() function.

# %% [markdown]
# ## Data exploration

# %%
file = "U.S._crude_oil_production.csv"
oil_df = pd.read_csv(file)
oil_df.head()
# Out:
#         Month  U.S. Crude Oil   Alabama  Alaska  Arkansas  Arizona  \
# 0  2008-06-01             5138       21     655        17        0
# 1  2008-07-01             5177       21     640        17        0
# 2  2008-08-01             5003       21     544        17        0
# 3  2008-09-01             3974       21     681        16        0
# 4  2008-10-01             4738       21     716        17        0
#
#    California  Colorado  Federal Offshore Gulf of Mexico Crude Oil  \
# 0         583        82                                       1326
# 1         586        81                                       1372
# 2         588        82                                       1272
# 3         587        88                                        242
# 4         586        86                                        803
#
#    Federal Offshore Pacific Crude Oil  ...  Ohio  Oklahoma  Pennsylvania  \
# 0                                  67  ...    14       186             8
# ...

# %% [markdown]
# Now we want to parse the Month column into a datetime object.

# %%
oil_df.dtypes
# Out:
# Month                                        object
# U.S. Crude Oil                                int64
# Alabama                                       int64
# Alaska                                        int64
# Arkansas                                      int64
# Arizona                                       int64
# California                                    int64
# Colorado                                      int64
# Federal Offshore Gulf of Mexico Crude Oil     int64
# Federal Offshore Pacific Crude Oil            int64
# Florida                                       int64
# Idaho                                         int64
# Illinois                                      int64
# Indiana                                       int64
# Kansas                                        int64
# Kentucky                                      int64
# Louisiana                                     int64
# Michigan                                      int64
# ...

# %%
oil_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 36 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Month                                      121 non-null    object
#  1   U.S. Crude Oil                             121 non-null    int64
#  2   Alabama                                    121 non-null    int64
#  3   Alaska                                     121 non-null    int64
#  4   Arkansas                                   121 non-null    int64
#  5   Arizona                                    121 non-null    int64
#  6   California                                 121 non-null    int64
#  7   Colorado                                   121 non-null    int64
#  8   Federal Offshore Gulf of Mexico Crude Oil  121 non-null    int64
#  9   Federal Offshore Pacific Crude Oil         121 non-null    int64
# ...

# %%
oil_df.head(10)
# Out:
#         Month  U.S. Crude Oil   Alabama  Alaska  Arkansas  Arizona  \
# 0  2008-06-01             5138       21     655        17        0
# 1  2008-07-01             5177       21     640        17        0
# 2  2008-08-01             5003       21     544        17        0
# 3  2008-09-01             3974       21     681        16        0
# 4  2008-10-01             4738       21     716        17        0
# 5  2008-11-01             5078       22     728        17        0
# 6  2008-12-01             5103       22     702        17        0
# 7  2009-01-01             5138       21     679        16        0
# 8  2009-02-01             5236       21     708        16        0
# 9  2009-03-01             5210       20     709        16        0
#
#    California  Colorado  Federal Offshore Gulf of Mexico Crude Oil  \
# 0         583        82                                       1326
# 1         586        81                                       1372
# ...

# %%
oil_df.columns
# Out:
# Index(['Month', 'U.S. Crude Oil', 'Alabama', 'Alaska', 'Arkansas', 'Arizona',
#        'California', 'Colorado', 'Federal Offshore Gulf of Mexico Crude Oil',
#        'Federal Offshore Pacific Crude Oil', 'Florida', 'Idaho', 'Illinois',
#        'Indiana', 'Kansas', 'Kentucky', 'Louisiana', 'Michigan', 'Mississippi',
#        'Missouri', 'Nebraska', 'Montana', 'Nevada', 'New Mexico', 'New York',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Pennsylvania', 'South Dakota',
#        'Wyoming', 'West Virginia', 'Virginia', 'Utah', 'Texas', 'Tennessee'],
#       dtype='object')

# %% [markdown]
# ## We need to clear columns we are using r for removing trailing

# %%
oil_df.columns = oil_df.columns.str.rstrip()
oil_df
# Out:
#           Month  U.S. Crude Oil  Alabama  Alaska  Arkansas  Arizona  \
# 0    2008-06-01            5138       21     655        17        0
# 1    2008-07-01            5177       21     640        17        0
# 2    2008-08-01            5003       21     544        17        0
# 3    2008-09-01            3974       21     681        16        0
# 4    2008-10-01            4738       21     716        17        0
# ..          ...             ...      ...     ...       ...      ...
# 116  2018-02-01           10248       17     513        14        0
# 117  2018-03-01           10461       17     512        14        0
# 118  2018-04-01           10475       17     497        14        0
# 119  2018-05-01           10443       16     496        14        0
# 120  2018-06-01           10674       16     451        14        0
#
#      California  Colorado  Federal Offshore Gulf of Mexico Crude Oil  \
# 0           583        82                                       1326
# ...

# %%
oil_df.dtypes
# Out:
# Month                                        object
# U.S. Crude Oil                                int64
# Alabama                                       int64
# Alaska                                        int64
# Arkansas                                      int64
# Arizona                                       int64
# California                                    int64
# Colorado                                      int64
# Federal Offshore Gulf of Mexico Crude Oil     int64
# Federal Offshore Pacific Crude Oil            int64
# Florida                                       int64
# Idaho                                         int64
# Illinois                                      int64
# Indiana                                       int64
# Kansas                                        int64
# Kentucky                                      int64
# Louisiana                                     int64
# Michigan                                      int64
# ...

# %% [markdown]
# #### Using datetime function to get each y m d seperate if we need to

# %%
oil_df["Month"] = pd.to_datetime(oil_df["Month"], format="%Y-%m-%d")
oil_df["Month"].dt.year.head()
# Out:
# 0    2008
# 1    2008
# 2    2008
# 3    2008
# 4    2008
# Name: Month, dtype: int64

# %%
gas_df["Month"] = pd.to_datetime(gas_df["Month"], format="%Y-%m-%d")
gas_df["Month"].dt.year.head()
# Out:
# 0    2008
# 1    2008
# 2    2008
# 3    2008
# 4    2008
# Name: Month, dtype: int64

# %% [markdown]
# Then create two dataframes yearly_gas and yearly_oil by grouping by year, summing and filtering the global production for both commodities. Rename the columns to Gas and Crude oil.

# %%
yearly_gas = gas_df.groupby(gas_df["Month"].dt.year).sum().filter(items=["U.S."])
yearly_gas.columns = ["Gas"]
yearly_gas.head()
# Out:
#           Gas
# Month
# 2008   489473
# 2009   856876
# 2010   881622
# 2011   936163
# 2012   968632

# %%
yearly_oil = oil_df.groupby(oil_df['Month'].dt.year).sum().filter(items=['U.S. Crude Oil'])
yearly_oil.columns = ["Crude Oil"]
yearly_oil.head()
# Out:
#        Crude Oil
# Month
# 2008       34211
# 2009       64180
# 2010       65741
# 2011       67829
# 2012       78007

# %%
yearly_merged = pd.concat([yearly_oil, yearly_gas], axis= "columns")

# %%
yearly_merged
# Out:
#        Crude Oil      Gas
# Month
# 2008       34211   489473
# 2009       64180   856876
# 2010       65741   881622
# 2011       67829   936163
# 2012       78007   968632
# 2013       89585   970617
# 2014      105064  1032439
# 2015      113179  1082158
# 2016      105970  1070085
# 2017      112205  1090730
# 2018       62296   587058

# %%
merged_plot = yearly_merged.plot(kind="bar")
merged_plot.set_xlabel("Year")
merged_plot.legend(['Gas (Millions of Cubic feet)', 'Crude Oil (Thousands of barrels)'])
